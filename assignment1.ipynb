# %%
name = "Stephen"
age = 31
state_of_residence = "Kaduna"
favorite_ai_tool = "ChatGPT"

print("my name is", name)
print("I am", age, "years old")
print("I live in", state_of_residence)
print("my favorite AI tool is", favorite_ai_tool)
# Out:
# my name is Stephen
# I am 31 years old
# I live in Kaduna
# my favorite AI tool is ChatGPT

# %%
name = "Stephen"
age = 31
state_of_residence = "Kaduna"
favorite_ai_tool = "ChatGPT"

print(f"My name is {name}")
print(f"I am {age} years old")
print(f"I live in {state_of_residence}")
print(f"my favorite AI tool is {favorite_ai_tool}")
# Out:
# My name is Stephen
# I am 31 years old
# I live in Kaduna
# my favorite AI tool is ChatGPT
