# %% [markdown]
# <a href="https://colab.research.google.com/github/area-ai-projects/AI-BUILDERS-BOOTCAMP/blob/main/Day_1_assignment_oluwaseyifunmi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment_1_My personal profile.ipynb

# %%
name = "Oluwaseyifunmi Efunkunle"
age = 26
state_of_residence = "Lagos"
favourite_ai_tool = "Gemini"


print("My Personal Profile")
print("Name:", name)
print("Age:", age)
print("State:", state_of_residence)
print("Favourite_AI_Tool:", favourite_ai_tool)
# Out:
# My Personal Profile
# Name: Oluwaseyifunmi Efunkunle
# Age: 26
# State: Lagos
# Favourite_AI_Tool: Gemini

# %% [markdown]
# Assignment_2_Data_types_practices.ipynb

# %%
# String
my_string = "Hello AI"

# Integer
my_int = 26

# Float
my_float = 2.15

# Boolean
my_boolean = True

# list (5 AI tools)
ai_tools = ["ChatGPT", "Gemini", "Claude" , "Copilot", "Canva"]

# Tuple
my_tuple = ("python", "AI", "ML")

# Dictionary
my_dict = {
    "name": "Oluwaseyifunmi Efunkunle",
     "age": 26,
     "skill": "virtual Assistant"

}


#printing values and their types
print(my_string, type(my_string))
print(my_int, type(my_int))
print(my_float, type(my_float))
print(my_boolean, type(my_boolean))
print(ai_tools, type(ai_tools))
print(my_tuple, type(my_tuple))
print(my_dict, type(my_dict))
# Out:
# Hello AI <class 'str'>
# 26 <class 'int'>
# 2.15 <class 'float'>
# True <class 'bool'>
# ['ChatGPT', 'Gemini', 'Claude', 'Copilot', 'Canva'] <class 'list'>
# ('python', 'AI', 'ML') <class 'tuple'>
# {'name': 'Oluwaseyifunmi Efunkunle', 'age': 26, 'skill': 'virtual Assistant'} <class 'dict'>

# %% [markdown]
# Assignment_3_strings operations.ipynb

# %%
# Given string
text = " welcome to python programming "

# Uppercase
print(text.upper())

#Lowercase
print(text.lower())

# Slicing(first 7 characters)
print(text[0:7])

#strip(remove extra spaces)
print(text.strip())

#Concatenation
new_text = text.strip() + "is fine!"
print(new_text)
# Out:
#  WELCOME TO PYTHON PROGRAMMING
#  welcome to python programming
#  welcom
# welcome to python programming
# welcome to python programmingis fine!
