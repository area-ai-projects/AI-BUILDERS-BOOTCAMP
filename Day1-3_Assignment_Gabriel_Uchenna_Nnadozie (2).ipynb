# %%
#Assignment

# %%
Name = 'Gabriel'
Age = '30'
State = 'River_State'
Favourite_ai = 'Grok'

# %%
print(Name)
print(Age)
print(State)
print(Favourite_ai)
# Out:
# Gabriel
# 30
# River_State
# Grok

# %%
#Data Types Practice

# %%
#String

# %%
Name = 'Gabriel Uchenna'

# %%
print(Name)
# Out:
# Gabriel Uchenna

# %%
#integer

# %%
Age = '30'

# %%
print(Age)
# Out:
# 30

# %%
#Float

# %%
24.6
# Out:
# 24.6

# %%
#Boolean

# %%
is_Gabriel_a_Saint = True

# %%
#list of Ai Tools

# %%
List = 'Grok_Claude_Chat_Klingai_Deep'

# %%
print(List)
# Out:
# Grok_Claude_Chat_Klingai_Deep

# %%
#Tuple

# %%
my Expertise = ('Logistics', 'Management', 'Python', 'Listerning')

# %%
#Dictionary

# %%
Student = {'Name': 'Gabriel', 'Age': 25, 'state': 'River'}

# %%
#3 String Operation

# %%
#uppercase

# %%
print(''\n=== String Operations ==='')

# %%
# Uppercase:'', text.upper())

# %%
print(''Uppercase:'', text.upper())

# %%
# Lowercase:'', text.lower())

# %%
print(''Lowercase:'', text.upper())

# %%
#Strip (remove spaces)

# %%
print(''Stripped:'', text.strip())

# %%
#Slicing

# %%
print(''Sliced:'', text[2:10])

# %%
#Concatenation

# %%
new_text = text.strip() + '' - Bootcamp''
