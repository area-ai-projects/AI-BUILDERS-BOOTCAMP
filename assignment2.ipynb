# %%
# string variable
name = "Stephen"

# Integer Variable
age = 31

# Float Variable
height = 6

# Booloean Variable
is_a_male = True

# printing the variables
print( "String:", name)
print("Integer:", age)
print("float:", height)
print("Boolean:", is_a_male)
# Out:
# String: Stephen
# Integer: 31
# float: 6
# Boolean: True

# %%
# list of 5 AI tools
ai_tools = ["ChatGPT", "Claude", "Copilot", "Gemini", "Perplexity"]

# Tuple
Colors = ( "White", "Black", "Red")

# Dictionary
Personal_information = {"name": "Stephen", "age": 31}


#Printing the Variables
print("String:", name)
print("Integer:", age)
print("float:", height)
print("Boolean:", is_a_male)

print("\nlist of AI Tools:")
print(ai_tools)

print("\nTuple:")
print(Colors)

print("\nDictionary:")
print(Personal_information)
# Out:
# String: Stephen
# Integer: 31
# float: 6
# Boolean: True
#
# list of AI Tools:
# ['ChatGPT', 'Claude', 'Copilot', 'Gemini', 'Perplexity']
#
# Tuple:
# ('White', 'Black', 'Red')
#
# Dictionary:
# {'name': 'Stephen', 'age': 31}
